# %% [markdown]
# # GoFish Python Wrapper - Test Notebook
#
# This notebook demonstrates the Python wrapper for GoFish graphics library.

# %% [markdown]
# ## Setup
#
# First, let's import the necessary libraries and create some sample data.

# %%
import pandas as pd
from gofish import chart, spread, stack, derive, rect, circle

# Create sample seafood data
seafood_data = [
  {
    "lake": "Lake A",
    "species": "Bass",
    "count": 23,
  },
  {
    "lake": "Lake A",
    "species": "Trout",
    "count": 31,
  },
  {
    "lake": "Lake A",
    "species": "Catfish",
    "count": 29,
  },
  {
    "lake": "Lake A",
    "species": "Perch",
    "count": 12,
  },
  {
    "lake": "Lake A",
    "species": "Salmon",
    "count": 8,
  },
  {
    "lake": "Lake B",
    "species": "Bass",
    "count": 25,
  },
  {
    "lake": "Lake B",
    "species": "Trout",
    "count": 34,
  },
  {
    "lake": "Lake B",
    "species": "Catfish",
    "count": 41,
  },
  {
    "lake": "Lake B",
    "species": "Perch",
    "count": 21,
  },
  {
    "lake": "Lake B",
    "species": "Salmon",
    "count": 16,
  },
  {
    "lake": "Lake C",
    "species": "Bass",
    "count": 15,
  },
  {
    "lake": "Lake C",
    "species": "Trout",
    "count": 25,
  },
  {
    "lake": "Lake C",
    "species": "Catfish",
    "count": 31,
  },
  {
    "lake": "Lake C",
    "species": "Perch",
    "count": 22,
  },
  {
    "lake": "Lake C",
    "species": "Salmon",
    "count": 31,
  },
  {
    "lake": "Lake D",
    "species": "Bass",
    "count": 12,
  },
  {
    "lake": "Lake D",
    "species": "Trout",
    "count": 17,
  },
  {
    "lake": "Lake D",
    "species": "Catfish",
    "count": 23,
  },
  {
    "lake": "Lake D",
    "species": "Perch",
    "count": 23,
  },
  {
    "lake": "Lake D",
    "species": "Salmon",
    "count": 41,
  },
  {
    "lake": "Lake E",
    "species": "Bass",
    "count": 7,
  },
  {
    "lake": "Lake E",
    "species": "Trout",
    "count": 9,
  },
  {
    "lake": "Lake E",
    "species": "Catfish",
    "count": 13,
  },
  {
    "lake": "Lake E",
    "species": "Perch",
    "count": 20,
  },
  {
    "lake": "Lake E",
    "species": "Salmon",
    "count": 40,
  },
  {
    "lake": "Lake F",
    "species": "Bass",
    "count": 4,
  },
  {
    "lake": "Lake F",
    "species": "Trout",
    "count": 7,
  },
  {
    "lake": "Lake F",
    "species": "Catfish",
    "count": 9,
  },
  {
    "lake": "Lake F",
    "species": "Perch",
    "count": 21,
  },
  {
    "lake": "Lake F",
    "species": "Salmon",
    "count": 47,
  },
]

seafood = pd.DataFrame(seafood_data)
print(seafood.head())
# Out:
#      lake  species  count
# 0  Lake A     Bass     23
# 1  Lake A    Trout     31
# 2  Lake A  Catfish     29
# 3  Lake A    Perch     12
# 4  Lake A   Salmon      8

# %% [markdown]
# ## Example 1: Basic Bar Chart
#
# A simple bar chart using the `spread` operator to arrange bars horizontally.

# %%
(
    chart(seafood)
    .flow(spread("lake", dir="x"))
    .mark(rect(h="count"))
    .render(w=500, h=300, axes=True)
)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <meta charset="UTF-8">
#   <style>
#     body { margin: 0; padding: 20px; font-family: sans-serif; }
#     svg { display: block; }
#   </style>
# </head>
# <body>
#   <svg xmlns="http://www.w3.org/2000/svg" width="660" height="460"><g transform="scale(1, -1) translate(40, -340)"><g transform="translate(0, 0) scale(1, 1)"><g transform="translate(0, 0)"><rect transform="scale(1, -1)" x="0" y="-225.54744525547446" width="76.66666666666667" height="225.54744525547446" fill="#4190c5" stroke="#4190c5" stroke-width="0"></rect><rect transform="scale(1, -1)" x="84.66666666666666" y="-300" width="76.66666666666667" height="300" fill="#4190c5" stroke="#4190c5" stroke-width="0"></rect><rect transform="scale(1, -1)" x="169.33333333333334" y="-271.53284671532845" width="76.66666666666667" height="271.53284671532845" fill="#4190c5" stroke="#4190c5" stroke-width="0"></rect><rect transform="scale(1, -1)" x="253.99999999999997" y="-254.01459854014598" width="76.66666666666667" height="254.01459854014598" fill="#4190c5" stroke="#4190c5" stroke-width="0"></rect><rect transform="scale(1, -1)" x="338.6666666666667" y="-194.8905109489051" width="76.66666666666667" height="194.8905109489051" fill="#4190c5" stroke="#4190c5" stroke-width="0"></rect><rect transform="scale(1, -1)" x="423.33333333333337" y="-192.7007299270073" width="76.66666666666667" height="192.7007299270073" fill="#4190c5" stroke="#4190c5" stroke-width="0"></rect></g></g><g><g><line x1="-10" x2="-10" stroke="gray" stroke-width="1px" y1="-0.5" y2="307.06934306569343"></line><text transform="scale(1, -1)" x="-17.5" text-anchor="end" dominant-baseline="middle" font-size="10px" fill="gray" y="0">0</text><line x1="-15" x2="-10" stroke="gray" y1="0" y2="0"></line><text transform="scale(1, -1)" x="-17.5" text-anchor="end" dominant-baseline="middle" font-size="10px" fill="gray" y="-21.8978102189781">10</text><line x1="-15" x2="-10" stroke="gray" y1="21.8978102189781" y2="21.8978102189781"></line><text transform="scale(1, -1)" x="-17.5" text-anchor="end" dominant-baseline="middle" font-size="10px" fill="gray" y="-43.7956204379562">20</text><line x1="-15" x2="-10" stroke="gray" y1="43.7956204379562" y2="43.7956204379562"></line><text transform="scale(1, -1)" x="-17.5" text-anchor="end" dominant-baseline="middle" font-size="10px" fill="gray" y="-65.69343065693431">30</text><line x1="-15" x2="-10" stroke="gray" y1="65.69343065693431" y2="65.69343065693431"></line><text transform="scale(1, -1)" x="-17.5" text-anchor="end" dominant-baseline="middle" font-size="10px" fill="gray" y="-87.5912408759124">40</text><line x1="-15" x2="-10" stroke="gray" y1="87.5912408759124" y2="87.5912408759124"></line><text transform="scale(1, -1)" x="-17.5" text-anchor="end" dominant-baseline="middle" font-size="10px" fill="gray" y="-109.48905109489051">50</text><line x1="-15" x2="-10" stroke="gray" y1="109.48905109489051" y2="109.48905109489051"></line><text transform="scale(1, -1)" x="-17.5" text-anchor="end" dominant-baseline="middle" font-size="10px" fill="gray" y="-131.38686131386862">60</text><line x1="-15" x2="-10" stroke="gray" y1="131.38686131386862" y2="131.38686131386862"></line><text transform="scale(1, -1)" x="-17.5" text-anchor="end" dominant-baseline="middle" font-size="10px" fill="gray" y="-153.28467153284672">70</text><line x1="-15" x2="-10" stroke="gray" y1="153.28467153284672" y2="153.28467153284672"></line><text transform="scale(1, -1)" x="-17.5" text-anchor="end" dominant-baseline="middle" font-size="10px" fill="gray" y="-175.1824817518248">80</text><line x1="-15" x2="-10" stroke="gray" y1="175.1824817518248" y2="175.1824817518248"></line><text transform="scale(1, -1)" x="-17.5" text-anchor="end" dominant-baseline="middle" font-size="10px" fill="gray" y="-197.08029197080293">90</text><line x1="-15" x2="-10" stroke="gray" y1="197.08029197080293" y2="197.08029197080293"></line><text transform="scale(1, -1)" x="-17.5" text-anchor="end" dominant-baseline="middle" font-size="10px" fill="gray" y="-218.97810218978103">100</text><line x1="-15" x2="-10" stroke="gray" y1="218.97810218978103" y2="218.97810218978103"></line><text transform="scale(1, -1)" x="-17.5" text-anc ...
# </body>
# </html>

# %% [markdown]
# ## Example 2: Stacked Bar Chart
#
# A stacked bar chart using both `spread` and `stack` operators.

# %%
(
    chart(seafood)
    .flow(
        spread("lake", dir="x"),
        stack("species", dir="y", label=False)
    )
    .mark(rect(h="count", fill="species"))
    .render(w=500, h=300, axes=True)
)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <meta charset="UTF-8">
#   <style>
#     body { margin: 0; padding: 20px; font-family: sans-serif; }
#     svg { display: block; }
#   </style>
# </head>
# <body>
#   <svg xmlns="http://www.w3.org/2000/svg" width="660" height="460"><g transform="scale(1, -1) translate(40, -340)"><g transform="translate(0, 0) scale(1, 1)"><g transform="translate(0, 0)"><g transform="translate(0, 0)"><rect transform="scale(1, -1)" x="0" y="-50.36496350364963" width="76.66666666666667" height="50.36496350364963" fill="#4190c5" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-118.24817518248175" width="76.66666666666667" height="67.88321167883211" fill="#f2cf57" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-181.75182481751824" width="76.66666666666667" height="63.503649635036496" fill="#a181c8" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-208.02919708029196" width="76.66666666666667" height="26.277372262773724" fill="#ff9666" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-225.54744525547446" width="76.66666666666667" height="17.518248175182492" fill="#43b780" stroke="[object Object]" stroke-width="0"></rect></g><g transform="translate(84.66666666666667, 0)"><rect transform="scale(1, -1)" x="0" y="-54.74452554744526" width="76.66666666666667" height="54.74452554744526" fill="#4190c5" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-129.1970802919708" width="76.66666666666667" height="74.45255474452554" fill="#f2cf57" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-218.978102189781" width="76.66666666666667" height="89.7810218978102" fill="#a181c8" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-264.963503649635" width="76.66666666666667" height="45.98540145985402" fill="#ff9666" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-300" width="76.66666666666667" height="35.036496350364985" fill="#43b780" stroke="[object Object]" stroke-width="0"></rect></g><g transform="translate(169.33333333333334, 0)"><rect transform="scale(1, -1)" x="0" y="-32.846715328467155" width="76.66666666666667" height="32.846715328467155" fill="#4190c5" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-87.5912408759124" width="76.66666666666667" height="54.74452554744525" fill="#f2cf57" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-155.47445255474452" width="76.66666666666667" height="67.88321167883211" fill="#a181c8" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-203.64963503649633" width="76.66666666666667" height="48.17518248175182" fill="#ff9666" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-271.53284671532845" width="76.66666666666667" height="67.88321167883211" fill="#43b780" stroke="[object Object]" stroke-width="0"></rect></g><g transform="translate(254, 0)"><rect transform="scale(1, -1)" x="0" y="-26.277372262773724" width="76.66666666666667" height="26.277372262773724" fill="#4190c5" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-63.503649635036496" width="76.66666666666667" height="37.22627737226277" fill="#f2cf57" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-113.86861313868613" width="76.66666666666667" height="50.36496350364963" fill="#a181c8" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-164.23357664233578" width="76.66666666666667" height="50.36496350364965" fill="#ff9666" stroke="[object Object]" stroke-width="0"></rect><rect transform="scale(1, -1)" x="0" y="-254.01459854014598" width="76.66666666666667" height="89.7810218978102" fill="#43b780" stroke="[object Object]" stroke-width="0"></rect></g><g transform="translate(338.6666666666667, 0)"><rect transform="scale(1, -1)" x="0" y="-15.32846 ...

# %% [markdown]
# ## Example 3: Stacked Bar Chart with Derive
#
# Using the `derive` operator to sort data before stacking.

# %%
(
    chart(seafood)
    .flow(
        spread("lake", dir="x"),
        derive(lambda d: d.sort_values("count")),
        stack("species", dir="y", label=False)
    )
    .mark(rect(h="count", fill="species"))
    .render(w=500, h=300, axes=True)
)
# Out:
# [DEBUG] Executing derive lambda 1174fc61-2989-4a52-ac6a-5c9920e8b270
# [DEBUG] DataFrame shape: (5, 3)
# [DEBUG] DataFrame columns: ['lake', 'species', 'count']
# [DEBUG] DataFrame dtypes:
# lake       category
# species    category
# count       float64
# dtype: object
# [DEBUG] DataFrame head:
#      lake  species  count
# 0  Lake A     Bass   23.0
# 1  Lake A    Trout   31.0
# 2  Lake A  Catfish   29.0
# 3  Lake A    Perch   12.0
# 4  Lake A   Salmon    8.0
# [DEBUG] DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   lake     5 non-null      category
#  1   species  5 non-null      category
#  2   count    5 non-null      float64
# dtypes: category(2), float64(1)
# memory usage: 506.0 bytes
#
# [DEBUG] Result DataFrame shape: (5, 3)
# [DEBUG] Result DataFrame columns: ['lake', 'species', 'count']
# [DEBUG] Result DataFrame head:
#      lake  species  count
# 4  Lake A   Salmon    8.0
# 3  Lake A    Perch   12.0
# 0  Lake A     Bass   23.0
# 2  Lake A  Catfish   29.0
# 1  Lake A    Trout   31.0
# [DEBUG] Executing derive lambda 1174fc61-2989-4a52-ac6a-5c9920e8b270
# [DEBUG] DataFrame shape: (5, 3)
# [DEBUG] DataFrame columns: ['lake', 'species', 'count']
# [DEBUG] DataFrame dtypes:
# lake       category
# species    category
# count       float64
# dtype: object
# [DEBUG] DataFrame head:
#      lake  species  count
# 0  Lake B     Bass   25.0
# 1  Lake B    Trout   34.0
# 2  Lake B  Catfish   41.0
# 3  Lake B    Perch   21.0
# 4  Lake B   Salmon   16.0
# [DEBUG] DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   lake     5 non-null      category
#  1   species  5 non-null      category
#  2   count    5 non-null      float64
# dtypes: category(2), float64(1)
# memory usage: 506.0 bytes
#
# [DEBUG] Result DataFrame shape: (5, 3)
# [DEBUG] Result DataFrame columns: ['lake', 'species', 'count']
# [DEBUG] Result DataFrame head:
#      lake  species  count
# 4  Lake B   Salmon   16.0
# 3  Lake B    Perch   21.0
# 0  Lake B     Bass   25.0
# 1  Lake B    Trout   34.0
# 2  Lake B  Catfish   41.0
# [DEBUG] Executing derive lambda 1174fc61-2989-4a52-ac6a-5c9920e8b270
# [DEBUG] DataFrame shape: (5, 3)
# [DEBUG] DataFrame columns: ['lake', 'species', 'count']
# [DEBUG] DataFrame dtypes:
# lake       category
# species    category
# count       float64
# dtype: object
# [DEBUG] DataFrame head:
#      lake  species  count
# 0  Lake C     Bass   15.0
# 1  Lake C    Trout   25.0
# 2  Lake C  Catfish   31.0
# 3  Lake C    Perch   22.0
# 4  Lake C   Salmon   31.0
# [DEBUG] DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   lake     5 non-null      category
#  1   species  5 non-null      category
#  2   count    5 non-null      float64
# dtypes: category(2), float64(1)
# memory usage: 506.0 bytes
#
# [DEBUG] Result DataFrame shape: (5, 3)
# [DEBUG] Result DataFrame columns: ['lake', 'species', 'count']
# [DEBUG] Result DataFrame head:
#      lake  species  count
# 0  Lake C     Bass   15.0
# 3  Lake C    Perch   22.0
# 1  Lake C    Trout   25.0
# 2  Lake C  Catfish   31.0
# 4  Lake C   Salmon   31.0
# [DEBUG] Executing derive lambda 1174fc61-2989-4a52-ac6a-5c9920e8b270
# [DEBUG] DataFrame shape: (5, 3)
# [DEBUG] DataFrame columns: ['lake', 'species', 'count']
# [DEBUG] DataFrame dtypes:
# lake       category
# species    category
# count       float64
# dtype: object
# [DEBUG] DataFrame head:
#      lake  species  count
# 0  Lake D     Bass   12.0
# 1  Lake D    Trout   17.0
# 2  Lake D  Catfish   23.0
# 3  Lake D    Perch   23.0
# 4  Lake D   Salmon   41.0
# [DEBUG] DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   lake     5 non-null      category
#  1   species  5 non-null      category
#  2   count    5 non-null      float64
# dtypes: category(2), float64(1)
# memory usage: 506.0 bytes
#
# [DEBUG] Result DataFrame shape: (5, 3)
# [DEBUG] Result DataFrame columns: ['lake', 'species', 'count']
# [DEBUG] Result DataFrame head:
#      lake  species  count
# 0  Lake D     Bass   12.0
# 1  Lake D    Trout   17.0
# 2  Lake D  Catfish   23.0
# 3  Lake D    Perch   23.0
# 4  Lake D   Salmon   41.0
# [DEBUG] Executing derive lambda 1174fc61-2989-4a52-ac6a-5c9920e8b270
# [DEBUG] DataFrame shape: (5, 3)
# [DEBUG] DataFrame columns: ['lake', 'species', 'count']
# [DEBUG] DataFrame dtypes:
# lake       category
# species    category
# count       float64
# dtype: object
# [DEBUG] DataFrame head:
#      lake  species  count
# 0  Lake E     Bass    7.0
# 1  Lake E    Trout    9.0
# 2  Lake E  Catfish   13.0
# 3  Lake E    Perch   20.0
# 4  Lake E   Salmon   40.0
# [DEBUG] DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   lake     5 non-null      category
#  1   species  5 non-null      category
#  2   count    5 non-null      float64
# dtypes: category(2), float64(1)
# memory usage: 506.0 bytes
#
# [DEBUG] Result DataFrame shape: (5, 3)
# [DEBUG] Result DataFrame columns: ['lake', 'species', 'count']
# [DEBUG] Result DataFrame head:
#      lake  species  count
# 0  Lake E     Bass    7.0
# 1  Lake E    Trout    9.0
# 2  Lake E  Catfish   13.0
# 3  Lake E    Perch   20.0
# 4  Lake E   Salmon   40.0
# [DEBUG] Executing derive lambda 1174fc61-2989-4a52-ac6a-5c9920e8b270
# [DEBUG] DataFrame shape: (5, 3)
# [DEBUG] DataFrame columns: ['lake', 'species', 'count']
# [DEBUG] DataFrame dtypes:
# lake       category
# species    category
# count       float64
# dtype: object
# [DEBUG] DataFrame head:
#      lake  species  count
# 0  Lake F     Bass    4.0
# 1  Lake F    Trout    7.0
# 2  Lake F  Catfish    9.0
# 3  Lake F    Perch   21.0
# 4  Lake F   Salmon   47.0
# [DEBUG] DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   lake     5 non-null      category
#  1   species  5 non-null      category
#  2   count    5 non-null      float64
# dtypes: category(2), float64(1)
# memory usage: 506.0 bytes
#
# [DEBUG] Result DataFrame shape: (5, 3)
# [DEBUG] Result DataFrame columns: ['lake', 'species', 'count']
# [DEBUG] Result DataFrame head:
#      lake  species  count
# 0  Lake F     Bass    4.0
# 1  Lake F    Trout    7.0
# 2  Lake F  Catfish    9.0
# 3  Lake F    Perch   21.0
# 4  Lake F   Salmon   47.0
# <!DOCTYPE html>
# <html>
# <head>
#   <meta charset="UTF-8">
#   <style>
#     body { margin: 0; padding: 20px; font-family: sans-serif; }
#     svg { display: block; }
#   </style>
# </head>
# <body>
#   <svg xmlns="http://www.w3.org/2000/svg" width="660" height="460"><g transform="scale(1, -1) translate(40, -340)"><g transform="translate(0, 0) scale(1, 1)"><g transform="translate(0, 0)"><g transform="translate(0, 0)"></g><g transform="translate(-Infinity, 0)"></g><g transform="translate(-Infinity, 0)"></g><g transform="translate(-Infinity, 0)"></g><g transform="translate(-Infinity, 0)"></g><g transform="translate(-Infinity, 0)"></g></g></g><g><g><line x1="-10" x2="-10" stroke="gray" stroke-width="1px" y1="NaN" y2="NaN"></line><text transform="scale(1, -1)" x="-17.5" text-anchor="end" dominant-baseline="middle" font-size="10px" fill="gray" y="NaN">0</text><line x1="-15" x2="-10" stroke="gray" y1="NaN" y2="NaN"></line></g><g><text transform="scale(1, -1)" text-anchor="middle" dominant-baseline="hanging" font-size="10px" fill="gray" x="0" y="5">Lake A</text><text transform="scale(1, -1)" text-anchor="middle" dominant-baseline="hanging" font-size="10px" fill="gray" x="-Infinity" y="5">Lake B</text><text transform="scale(1, -1)" text-anchor="middle" dominant-baseline="hanging" font-size="10px" fill="gray" x="-Infinity" y="5">Lake C</text><text transform="scale(1, -1)" text-anchor="middle" dominant-baseline="hanging" font-size="10px" fill="gray" x="-Infinity" y="5">Lake D</text><text transform="scale(1, -1)" text-anchor="middle" dominant-baseline="hanging" font-size="10px" fill="gray" x="-Infinity" y="5">Lake E</text><text transform="scale(1, -1)" text-anchor="middle" dominant-baseline="hanging" font-size="10px" fill="gray" x="-Infinity" y="5">Lake F</text></g><g></g></g></g></svg>
# </body>
# </html>

# %% [markdown]
# ## Notes
#
# - The `derive` function allows you to run arbitrary Python code on DataFrames
# - Data is converted to Apache Arrow format for efficient transfer to JavaScript
# - Charts are rendered using the GoFish JavaScript library via a Node.js bridge
# - In Jupyter notebooks, charts are displayed inline using HTML
# - In standalone Python scripts, charts are saved to HTML files and opened in a browser
